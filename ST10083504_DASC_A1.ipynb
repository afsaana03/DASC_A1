# %% [markdown]
# Imports for the different libraries
# (Geeksforgeeks, 2024).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# The following code reads the CSV file  'spotify_songs.csv' using the pandas library and prints the first 5 rows (Geeksforgeeks, 2024).

# %%
import pandas as pd
# Reading the CSV file
df = pd.read_csv('C:\\Users\lab_services_student\Downloads\spotify_songs.csv')
# Printing top 5 rows
df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %% [markdown]
# df.shape is a pandas DataFrame attribute that returns data representing the dimensions of the DataFrame. The data contains two elements: the number of rows and the number of columns, respectively (Geeksforgeeks, 2024).

# %%
df.shape
# Out:
# (32833, 23)

# %% [markdown]
# This means that the DataFrame 'df' contains 32833 rows and 23 columns.

# %% [markdown]
# df.info() is a method in pandas used to print a summary of a DataFrame, including its index dtype and column dtypes, non-null values, and memory usage (Geeksforgeeks, 2024).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
# ...

# %% [markdown]
# df.describe() is a method in pandas used to generate descriptive statistics of the numerical columns in a DataFrame (Geeksforgeeks, 2024).
# Count: The number of non-null values in each column.
# Mean: The average value of each column (Geeksforgeeks, 2024).
# Standard deviation (std): A measure of the dispersion or spread of values around the mean.
# Minimum (min): The smallest value in each column (Geeksforgeeks, 2024).
# 25th percentile (25%): The value below which 25% of the data falls.
# Median (50%): The middle value of the dataset.
# 75th percentile (75%): The value below which 75% of the data falls.
# Maximum (max): The largest value in each column.
# This method provides a quick summary of the distribution of numerical data in the DataFrame, helping to identify outliers, assess the central tendency, and understand the spread of values (Geeksforgeeks, 2024).

# %%
df.describe()
# Out:
#        track_popularity  danceability        energy           key  \
# count      32833.000000  32833.000000  32833.000000  32833.000000
# mean          42.477081      0.654850      0.698619      5.374471
# std           24.984074      0.145085      0.180910      3.611657
# min            0.000000      0.000000      0.000175      0.000000
# 25%           24.000000      0.563000      0.581000      2.000000
# 50%           45.000000      0.672000      0.721000      6.000000
# 75%           62.000000      0.761000      0.840000      9.000000
# max          100.000000      0.983000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  32833.000000  32833.000000  32833.000000  32833.000000
# mean      -6.719499      0.565711      0.107068      0.175334
# std        2.988436      0.495671      0.101314      0.219633
# min      -46.448000      0.000000      0.000000      0.000000
# ...

# %% [markdown]
# df.isnull().sum() is a pandas DataFrame method that returns the number of missing values (null or NaN) in each column of the DataFrame.
# (Geeksforgeeks, 2024).
# When you call df.isnull().sum(), it will iterate through each column of the DataFrame (df), check for missing values, and then sum up the counts of missing values for each column (Geeksforgeeks, 2024).

# %%
df.isnull().sum()
# Out:
# track_id                    0
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_id              0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %% [markdown]
# Check if there any duplicate values (Geeksforgeeks, 2024).

# %%
df.duplicated().any()
# Out:
# False

# %%
df.nunique()
# Out:
# track_id                    28356
# track_name                  23449
# track_artist                10692
# track_popularity              101
# track_album_id              22545
# track_album_name            19743
# track_album_release_date     4530
# playlist_name                 449
# playlist_id                   471
# playlist_genre                  6
# playlist_subgenre              24
# danceability                  822
# energy                        952
# key                            12
# loudness                    10222
# mode                            2
# speechiness                  1270
# acousticness                 3731
# instrumentalness             4729
# liveness                     1624
# valence                      1362
# tempo                       17684
# duration_ms                 19785
# dtype: int64

# %% [markdown]
# Sorting values (Geeksforgeeks, 2024).

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# track_artist                5
# track_album_name            5
# track_name                  5
# track_id                    0
# key                         0
# tempo                       0
# valence                     0
# liveness                    0
# instrumentalness            0
# acousticness                0
# speechiness                 0
# mode                        0
# loudness                    0
# danceability                0
# energy                      0
# playlist_subgenre           0
# playlist_genre              0
# playlist_id                 0
# playlist_name               0
# track_album_release_date    0
# track_album_id              0
# track_popularity            0
# duration_ms                 0
# dtype: int64

# %%
df[df['track_artist'].isna()==True]
# Out:
#                      track_id track_name track_artist  track_popularity  \
# 8151   69gRFGOWY9OMpFJgFol1u0        NaN          NaN                 0
# 9282   5cjecvX0CmC9gK0Laf5EMQ        NaN          NaN                 0
# 9283   5TTzhRSWQS4Yu8xTgAuq6D        NaN          NaN                 0
# 19568  3VKFip3OdAvv4OfNTgFWeQ        NaN          NaN                 0
# 19811  69gRFGOWY9OMpFJgFol1u0        NaN          NaN                 0
#
#                track_album_id track_album_name track_album_release_date  \
# 8151   717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
# 9282   3luHJEPw434tvNbme3SP8M              NaN               2017-12-01
# 9283   3luHJEPw434tvNbme3SP8M              NaN               2017-12-01
# 19568  717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
# 19811  717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
#
#             playlist_name             playlist_id playlist_genre  ... key  \
# ...

# %% [markdown]
# drop null values (Geeksforgeeks, 2024).

# %%
cleaned_data = df.dropna()
cleaned_data.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %% [markdown]
# Check if any null values(Geeksforgeeks, 2024).

# %%
cleaned_data.isna().any().sum()
# Out:
# 0

# %%
cleaned_data['track_album_release_date'].dtype
# Out:
# dtype('O')

# %%
cleaned_data['track_album_release_date'].value_counts()
# Out:
# track_album_release_date
# 2020-01-10    270
# 2019-11-22    244
# 2019-12-06    235
# 2019-12-13    220
# 2013-01-01    219
#              ...
# 1973-08-28      1
# 2000-03-23      1
# 1967-04         1
# 1968-07-03      1
# 2014-04-18      1
# Name: count, Length: 4529, dtype: int64

# %%
cleaned_data['album_release_year'] = pd.DatetimeIndex(cleaned_data['track_album_release_date']).year
# Out:
# C:\Users\lab_services_student\AppData\Local\Temp\ipykernel_552\4113205604.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['album_release_year'] = pd.DatetimeIndex(cleaned_data['track_album_release_date']).year

# %%
cleaned_data['album_release_month'] = pd.DatetimeIndex(cleaned_data['track_album_release_date']).month
# Out:
# C:\Users\lab_services_student\AppData\Local\Temp\ipykernel_552\517675221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['album_release_month'] = pd.DatetimeIndex(cleaned_data['track_album_release_date']).month

# %% [markdown]
# Printing top rows of cleaned data (Geeksforgeeks, 2024).

# %%
cleaned_data.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
cleaned_data.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'album_release_year', 'album_release_month'],
#       dtype='object')

# %% [markdown]
# shows track popularity (Geeksforgeeks, 2024).

# %%
sns.histplot(data=cleaned_data, x='track_popularity',kde=True, color='orange')
plt.show()

# %% [markdown]
# The pairplot visually represents these relationships by plotting each of the selected musical attributes against the others, allowing for the observation of patterns specific to each genre (Geeksforgeeks, 2024). The hue parameter (playlist_genre) highlights how different genres cluster around certain attribute values, making it easier to see trends like those described above (Geeksforgeeks, 2024).
#
# This kind of analysis is valuable for understanding the distinct characteristics of various music genres and how they relate to listener experiences, such as energy levels and danceability, which can influence mood and activity (Geeksforgeeks, 2024). It also provides insights into how specific attributes are distributed within and across genres, which can be useful for tasks like music recommendation or playlist curation (Geeksforgeeks, 2024).

# %%
selected_columns = ['energy', 'danceability', 'valence', 'playlist_genre']

# %%
sns.pairplot(cleaned_data[selected_columns], hue='playlist_genre')
plt.show()
# Out:
# c:\tools\Anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Observations from the Pairplot:
# EDM Songs:
#
# Energy and Valence: Songs in the EDM (Electronic Dance Music) genre tend to be more energetic and possess a higher valence. Valence is a measure of the musical positivity conveyed by a track, with higher values indicating more positive or upbeat songs. The combination of high energy and high valence suggests that EDM tracks are typically lively, intense, and uplifting, which aligns with the genre's characteristic high-energy beats and vibrant atmosphere.
# R&B Genre:
#
# Energy Levels: On the other hand, R&B (Rhythm and Blues) tracks generally exhibit lower energy levels compared to EDM. R&B music often emphasizes smooth, soulful melodies and emotional depth, which may explain the lower energy observed in these tracks. This genre is more likely to feature slower tempos and softer sounds, contributing to a more relaxed and mellow listening experience.
# Latin Genre:
#
# Danceability: The Latin genre stands out as being particularly suitable for dancing, as indicated by higher danceability scores. Danceability describes how suitable a track is for dancing, and the Latin genre, with its rhythmic beats and lively tempos, naturally encourages movement. This aligns with the cultural significance of dance in Latin music, where rhythms like salsa, reggaeton, and samba are central to the genre's identity.
# Rap Songs:
#
# Diverse Energy and Danceability: Rap songs in the dataset show a wide range of energy levels, with some tracks being very low in energy while others are quite high. This diversity reflects the broad spectrum of styles within the rap genre, from slow, lyrical tracks to fast-paced, high-energy anthems. Additionally, some rap songs exhibit high danceability and valence, suggesting that while they might maintain the rhythmic and lyrical complexity typical of rap, they can also be upbeat and dance-friendly.

# %% [markdown]
# Pie chart: different genres (Geeksforgeeks, 2024).

# %%
custom_colors = ['purple', 'lightblue', 'green', 'pink', 'orange','lightgreen',]
paper = plt.figure(figsize=[10,6])
cleaned_data['playlist_genre'].value_counts().plot.pie(autopct='%3.1f%%',colors=custom_colors)
plt.title('Genre')
plt.show()

# %% [markdown]
# This is using Matplotlib to create a bar chart that visualizes the top 10 most common playlist_subgenre values from the cleaned_data dataset (Geeksforgeeks, 2024).

# %%
cleaned_data['playlist_subgenre'].value_counts()
paper = plt.figure(figsize=(15,7))

cleaned_data['playlist_subgenre'].value_counts()[:10].plot.bar(color='lightblue')
plt.title('playlist_subgenre',size=14)
plt.xlabel('palylist_subgenre',size=12)
plt.ylabel('Count',size=12)
plt.xticks(rotation=45)
plt.show()

# %%
print(cleaned_data['album_release_year'].max())
print(cleaned_data['album_release_year'].min())

# year with releases
cleaned_data['album_release_year'].value_counts()
# Out:
# 2020
# 1957
# album_release_year
# 2019    9081
# 2018    3312
# 2017    2428
# 2016    2127
# 2015    1779
#         ...
# 1960       4
# 1962       2
# 1957       2
# 1958       1
# 1961       1
# Name: count, Length: 63, dtype: int64

# %% [markdown]
# This generates a bar chart that visualizes the top 10 years with the highest number of album releases from the cleaned_data dataset (Geeksforgeeks, 2024).

# %%
paper = plt.figure(figsize=(15,7))
cleaned_data['album_release_year'].value_counts()[:10].sort_values(ascending=False).plot.bar(edgecolor='red', color='yellow')
plt.xlabel('Year',size=15)
plt.ylabel('Count',size=15)
plt.title('No. of Album Release Year wise',size=17)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Reference list:
#
# Geeksforgeeks. 2024. EDA | Exploratory Data Analysis in Python,02 July 2024. [Online]. Available at: https://www.geeksforgeeks.org/exploratory-data-analysis-in-python/ [Accessed 01 September 2024].
